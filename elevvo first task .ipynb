# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt  
import seaborn as sns

# %%
data=pd.read_csv(r"C:\Users\HP\Downloads\study_hours_scores_regression (1).csv")
data
# Out:
#     Hours  Scores
# 0    8.87   90.00
# 1    3.00   51.88
# 2    7.08   85.64
# 3    4.00   51.23
# 4    9.23   96.27
# ..    ...     ...
# 95   3.39    0.46
# 96  10.00   99.42
# 97   2.12   42.63
# 98   3.33   30.99
# 99   5.89   65.19
#
# [100 rows x 2 columns]

# %%
''' first we divide the data to x and y 
x => should be matrix 
y => should be vector 
'''
# Out:
# ' first we divide the data to x and y \nx => should be matrix \ny => should be vector \n'

# %%
x=data.iloc[:,[0]].values

# %%
y=data.iloc[:,1].values

# %%
from sklearn.model_selection import train_test_split

# %%
''' we divide our data to train and test '''
# Out:
# ' we divide our data to train and test '

# %%
x_train ,x_test,y_train,y_test=train_test_split(x,y,test_size=.2)

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor = LinearRegression()

# %%
''' fit function is step to train data'''
# Out:
# ' fit function is step to train data'

# %%
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
''' testing step '''
# Out:
# ' testing step '

# %%
ypred=regressor.predict(x_test)

# %%
# evaluation of model 
from sklearn.metrics import mean_absolute_percentage_error
print (mean_absolute_percentage_error(y_test , ypred))
# Out:
# 0.2615399932306387

# %%
print(f"MAE : {regressor.predict([[3]])}")
# Out:
# MAE : [28.27671987]

# %%
from sklearn.metrics import r2_score

# %%
r2 = r2_score(y_test, ypred)

# %%
print(f" R² Score: {r2:.4f}")
# Out:
#  R² Score: 0.6378

# %%
plt.scatter(x_train ,y_train)
plt.plot(x_train ,regressor.predict(x_train),color='red')
plt.xlabel("Hours of study")
plt.ylabel("Degree")
# Out:
# Text(0, 0.5, 'Degree')

# %%
# 2. Histograms
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
sns.histplot(data['Hours'], bins=20, kde=True, color='green')
plt.title('Distribution of Study Hours')
# Out:
# Text(0.5, 1.0, 'Distribution of Study Hours')

# %%
# box blot 
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
sns.boxplot(y=data['Hours'], color='green')
plt.title('Box Plot of Study Hours')

plt.subplot(1, 2, 2)
sns.boxplot(y=data['Scores'], color='orange')
plt.title('Box Plot of Exam Scores')
plt.tight_layout()
plt.show()
